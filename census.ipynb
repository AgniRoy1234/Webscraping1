# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
matrix=pd.read_html("https://en.wikipedia.org/wiki/List_of_states_in_India_by_past_population")

# %%
matrix
# Out:
# [     Rank     State or union territory  Population (1951 Census)[11]  \
#  0       1                Uttar Pradesh                    60274800.0
#  1       2                  Maharashtra                    32002500.0
#  2       3                        Bihar                    29085900.0
#  3       4                  West Bengal                    26300670.0
#  4       5               Madhya Pradesh                    18615700.0
#  5       6                   Tamil Nadu                    30119680.0
#  6       7                    Rajasthan                    15971130.0
#  7       8                    Karnataka                    19402500.0
#  8       9                      Gujarat                    16263700.0
#  9      10               Andhra Pradesh                    31115000.0
#  10     11                       Odisha                    14646100.0
#  11     12                    Telangana                           NaN
# ...

# %%
len(matrix)
# Out:
# 2

# %%
matrix[0]
# Out:
#      Rank     State or union territory  Population (1951 Census)[11]  \
# 0       1                Uttar Pradesh                    60274800.0
# 1       2                  Maharashtra                    32002500.0
# 2       3                        Bihar                    29085900.0
# 3       4                  West Bengal                    26300670.0
# 4       5               Madhya Pradesh                    18615700.0
# 5       6                   Tamil Nadu                    30119680.0
# 6       7                    Rajasthan                    15971130.0
# 7       8                    Karnataka                    19402500.0
# 8       9                      Gujarat                    16263700.0
# 9      10               Andhra Pradesh                    31115000.0
# 10     11                       Odisha                    14646100.0
# 11     12                    Telangana                           NaN
# 12     13                       Kerala                    13549000.0
# ...

# %%
data=matrix[0]

# %%
data[data["State or union territory"]=="Kerala"]
# Out:
#    Rank State or union territory  Population (1951 Census)[11]  \
# 12   13                   Kerala                    13549000.0
#
#     Population (1961 Census)[11]  Population (1971 Census)[11]  \
# 12                    16904560.0                    21347300.0
#
#     Population (1981 Census)[11]  Population (1991 Census)[11]  \
# 12                    25453680.0                    29098523.0
#
#     Population (2001 Census)[11]  Population (2011 Census)[11]
# 12                    31839000.0                      33387677

# %%
data[data["State or union territory"]=="Himachal Pradesh"]
# Out:
#    Rank State or union territory  Population (1951 Census)[11]  \
# 20   21         Himachal Pradesh                     2386940.0
#
#     Population (1961 Census)[11]  Population (1971 Census)[11]  \
# 20                     2812300.0                     3460434.0
#
#     Population (1981 Census)[11]  Population (1991 Census)[11]  \
# 20                     4280818.0                     5170877.0
#
#     Population (2001 Census)[11]  Population (2011 Census)[11]
# 20                     6077453.0                       6856509

# %%
data
# Out:
#      Rank     State or union territory  Population (1951 Census)[11]  \
# 0       1                Uttar Pradesh                    60274800.0
# 1       2                  Maharashtra                    32002500.0
# 2       3                        Bihar                    29085900.0
# 3       4                  West Bengal                    26300670.0
# 4       5               Madhya Pradesh                    18615700.0
# 5       6                   Tamil Nadu                    30119680.0
# 6       7                    Rajasthan                    15971130.0
# 7       8                    Karnataka                    19402500.0
# 8       9                      Gujarat                    16263700.0
# 9      10               Andhra Pradesh                    31115000.0
# 10     11                       Odisha                    14646100.0
# 11     12                    Telangana                           NaN
# 12     13                       Kerala                    13549000.0
# ...

# %%
Kerala=data[data["State or union territory"]=="Kerala"]

# %%
HP=data[data["State or union territory"]=="Himachal Pradesh"]

# %%
Kerala
# Out:
#    Rank State or union territory  Population (1951 Census)[11]  \
# 12   13                   Kerala                    13549000.0
#
#     Population (1961 Census)[11]  Population (1971 Census)[11]  \
# 12                    16904560.0                    21347300.0
#
#     Population (1981 Census)[11]  Population (1991 Census)[11]  \
# 12                    25453680.0                    29098523.0
#
#     Population (2001 Census)[11]  Population (2011 Census)[11]
# 12                    31839000.0                      33387677

# %%
HP
# Out:
#    Rank State or union territory  Population (1951 Census)[11]  \
# 20   21         Himachal Pradesh                     2386940.0
#
#     Population (1961 Census)[11]  Population (1971 Census)[11]  \
# 20                     2812300.0                     3460434.0
#
#     Population (1981 Census)[11]  Population (1991 Census)[11]  \
# 20                     4280818.0                     5170877.0
#
#     Population (2001 Census)[11]  Population (2011 Census)[11]
# 20                     6077453.0                       6856509

# %%
HP.iloc[:,2:-1].columns
# Out:
# Index(['Population (1951 Census)[11]', 'Population (1961 Census)[11]',
#        'Population (1971 Census)[11]', 'Population (1981 Census)[11]',
#        'Population (1991 Census)[11]', 'Population (2001 Census)[11]'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
plt.title("Population distibution of Himachal Pradesh")
plt.xticks(np.arange(0,7),"1951 1961 1971 1981 1991 2001 2011".split())
plt.bar(HP.iloc[:,2:-1].columns,HP.iloc[:,2:-1].values[0])
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(figsize=(20,10))
plt.title("Population distribution of Kerala")
plt.xticks(np.arange(0,7),"1951 1961 1971 1981 1991 2001 2011".split())
plt.bar(Kerala.iloc[:,2:-1].columns,HP.iloc[:,2:-1].values[0])
# Out:
# <BarContainer object of 6 artists>
